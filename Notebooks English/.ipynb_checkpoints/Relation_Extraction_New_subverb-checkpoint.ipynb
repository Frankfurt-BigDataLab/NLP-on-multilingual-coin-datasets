# %%
import sys
sys.path.append('../')
import pandas as pd
import random
import os
import numpy as np
import swifter

from cnt.model import (DesignEstimator, RelationExtractor, save_pipeline, load_pipeline, predict_re_single_sentence, 
relations_from_adjectives_df, relations_from_adjectives_single, concat_relations)
from cnt.annotate import (annotate, annotate_single_design, 
                          annotate_designs, 
                          extract_string_from_annotation, labeling_eng)
from cnt.extract_relation_single_verb import (path, NERTransformer, FeatureExtractor, RelationExtractor)
#from cnt.extract_relation import (path, NERTransformer, FeatureExtractor)
from cnt.evaluate import Metrics
from cnt.vectorize import (Doc2Str, Path2Str, Verbs2Str, AveragedPath2Vec, 
                           AveragedRest2Vec)
from cnt.io import (replace_left_right)
from cnt.io import  Database_Connection
from cnt.preprocess import Preprocess


from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline, make_union
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import Normalizer
from sklearn.naive_bayes import MultinomialNB
from itertools import product
import warnings
warnings.filterwarnings('ignore')

# %%
# Database access in text file: "mysql+mysqlconnector://root:YourConnection" -> Format user:password@IP/Database
f = open("/home/bigdatalab/Projects/D4N4/NLP_release_1.0/db_access.txt", "r")
access = f.read()
dc =  Database_Connection(access)

# %%
# Define all variables
id_col = "id" 
design_col = "design_en"
language = "_en"
add_columns = ["id", "name"+language, "alternativenames"+language, "class"]
id_col_RE = "design_id"
design_col_RE = "design_en"
ner_model_directory = "../cnt/trained_model/ner/english_new_single/" # for loading NER
ner_model_name = "english_cno"
re_model_directory = "../cnt/trained_model/re_subverb/"  # to save/load RE
re_model_name = "english_cno_new"

# %%
# optional - if already defined above
id_col = "id"
design_col = "design_en"
language = "_en"
add_columns = ["id", "name"+language, "alternativenames"+language, "class"]

# %%
# Get the annotated designs (ground truth) from the database
# ... under investigation
train = dc.create_own_query("""select design_id, 
(select design_en from nlp_training_designs as nlp where re.design_id=nlp.id) as design_en,
(select name_en from nlp_list_entities as ner where ner.id=re.subject) as s, 
(select class from nlp_list_entities as ner where ner.id=re.subject) as subject_class, 
(select name_en from nlp_list_entities as ner where ner.id=re.predicate) as p, 
(select name_en from nlp_list_entities as ner where ner.id=re.object) as o 
from nlp_relation_extraction_en_sub_verb as re;""")

# %%
train.head(5)
# Out:
#    design_id                                          design_en  \
# 0          9  Amphora with ribbed surface and crooked handle...
# 1         10  Bust of youthful Anchialos, right, wearing tae...
# 2         24  Bare-headed bust of Antoninus Pius, right, wea...
# 3         27  Laureate bust of Antoninus Pius, right, wearin...
# 4         28  Laureate bust of Antoninus Pius, right, wearin...
#
#                 s subject_class        p        o
# 0         amphora        OBJECT  holding  holding
# 1       Anchialos        PERSON  wearing  wearing
# 2  Antoninus Pius        PERSON  wearing  wearing
# 3  Antoninus Pius        PERSON  wearing  wearing
# 4  Antoninus Pius        PERSON  wearing  wearing

# %%
train.shape
# Out:
# (2067, 6)

# %%
# merging s, p, o to one triple into an array of length 1 for each entry - number of rows stay the same
train["y"] = train.apply(lambda row: [(row.s, row.subject_class, row.p, row.o)], axis=1)

# %%
train.head(2).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1800f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1800f_level0_col0" class="col_heading level0 col0" >design_id</th>
#       <th id="T_1800f_level0_col1" class="col_heading level0 col1" >design_en</th>
#       <th id="T_1800f_level0_col2" class="col_heading level0 col2" >s</th>
#       <th id="T_1800f_level0_col3" class="col_heading level0 col3" >subject_class</th>
#       <th id="T_1800f_level0_col4" class="col_heading level0 col4" >p</th>
#       <th id="T_1800f_level0_col5" class="col_heading level0 col5" >o</th>
#       <th id="T_1800f_level0_col6" class="col_heading level0 col6" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1800f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1800f_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_1800f_row0_col1" class="data row0 col1" >Amphora with ribbed surface and crooked handles containing two ears of corn and poppy.</td>
#       <td id="T_1800f_row0_col2" class="data row0 col2" >amphora</td>
#       <td id="T_1800f_row0_col3" class="data row0 col3" >OBJECT</td>
#       <td id="T_1800f_row0_col4" class="data row0 col4" >holding</td>
#       <td id="T_1800f_row0_col5" class="data row0 col5" >holding</td>
#       <td id="T_1800f_row0_col6" class="data row0 col6" >[('amphora', 'OBJECT', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_1800f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1800f_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_1800f_row1_col1" class="data row1 col1" >Bust of youthful Anchialos, right, wearing taenia. Border of dots.</td>
#       <td id="T_1800f_row1_col2" class="data row1 col2" >Anchialos</td>
#       <td id="T_1800f_row1_col3" class="data row1 col3" >PERSON</td>
#       <td id="T_1800f_row1_col4" class="data row1 col4" >wearing</td>
#       <td id="T_1800f_row1_col5" class="data row1 col5" >wearing</td>
#       <td id="T_1800f_row1_col6" class="data row1 col6" >[('Anchialos', 'PERSON', 'wearing', 'wearing')]</td>
#     </tr>
#   </tbody>
# </table>

# %%
# needed for the later merge
tmp = train.groupby("design_id").agg({"y": "sum"})

# %%
tmp.loc[tmp.index==1].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c399">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c399_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >design_id</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
X = train

# %%
# entries for one design are merged --> arrays contain all triples for each design
X = X.merge(tmp, left_on="design_id", right_on="design_id", suffixes=('', 'y'))

# %%
X = X[["design_id", "design_en", "yy"]].rename(columns={"yy":"y"})

# %%
X.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_52b5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52b5f_level0_col0" class="col_heading level0 col0" >design_id</th>
#       <th id="T_52b5f_level0_col1" class="col_heading level0 col1" >design_en</th>
#       <th id="T_52b5f_level0_col2" class="col_heading level0 col2" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52b5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52b5f_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_52b5f_row0_col1" class="data row0 col1" >Amphora with ribbed surface and crooked handles containing two ears of corn and poppy.</td>
#       <td id="T_52b5f_row0_col2" class="data row0 col2" >[('amphora', 'OBJECT', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52b5f_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_52b5f_row1_col1" class="data row1 col1" >Bust of youthful Anchialos, right, wearing taenia. Border of dots.</td>
#       <td id="T_52b5f_row1_col2" class="data row1 col2" >[('Anchialos', 'PERSON', 'wearing', 'wearing')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52b5f_row2_col0" class="data row2 col0" >24</td>
#       <td id="T_52b5f_row2_col1" class="data row2 col1" >Bare-headed bust of Antoninus Pius, right, wearing cuirass and paludamentum.</td>
#       <td id="T_52b5f_row2_col2" class="data row2 col2" >[('Antoninus Pius', 'PERSON', 'wearing', 'wearing')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52b5f_row3_col0" class="data row3 col0" >27</td>
#       <td id="T_52b5f_row3_col1" class="data row3 col1" >Laureate bust of Antoninus Pius, right, wearing cuirass and paludamentum.</td>
#       <td id="T_52b5f_row3_col2" class="data row3 col2" >[('Antoninus Pius', 'PERSON', 'wearing', 'wearing')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_52b5f_row4_col0" class="data row4 col0" >28</td>
#       <td id="T_52b5f_row4_col1" class="data row4 col1" >Laureate bust of Antoninus Pius, right, wearing paludamentum.</td>
#       <td id="T_52b5f_row4_col2" class="data row4 col2" >[('Antoninus Pius', 'PERSON', 'wearing', 'wearing')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_52b5f_row5_col0" class="data row5 col0" >33</td>
#       <td id="T_52b5f_row5_col1" class="data row5 col1" >Half-nude Aphrodite standing facing, head left, holding apple in raised right hand.</td>
#       <td id="T_52b5f_row5_col2" class="data row5 col2" >[('Aphrodite', 'PERSON', 'standing', 'standing'), ('Aphrodite', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_52b5f_row6_col0" class="data row6 col0" >33</td>
#       <td id="T_52b5f_row6_col1" class="data row6 col1" >Half-nude Aphrodite standing facing, head left, holding apple in raised right hand.</td>
#       <td id="T_52b5f_row6_col2" class="data row6 col2" >[('Aphrodite', 'PERSON', 'standing', 'standing'), ('Aphrodite', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_52b5f_row7_col0" class="data row7 col0" >36</td>
#       <td id="T_52b5f_row7_col1" class="data row7 col1" >Nude Aphrodite standing facing, head right, covering her breasts with right hand and pudenda with left hand; to left, Eros, riding a dolphin downwards.</td>
#       <td id="T_52b5f_row7_col2" class="data row7 col2" >[('Aphrodite', 'PERSON', 'standing', 'standing'), ('Aphrodite', 'PERSON', 'holding', 'holding'), ('Eros', 'PERSON', 'seated_on', 'seated_on')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_52b5f_row8_col0" class="data row8 col0" >36</td>
#       <td id="T_52b5f_row8_col1" class="data row8 col1" >Nude Aphrodite standing facing, head right, covering her breasts with right hand and pudenda with left hand; to left, Eros, riding a dolphin downwards.</td>
#       <td id="T_52b5f_row8_col2" class="data row8 col2" >[('Aphrodite', 'PERSON', 'standing', 'standing'), ('Aphrodite', 'PERSON', 'holding', 'holding'), ('Eros', 'PERSON', 'seated_on', 'seated_on')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_52b5f_row9_col0" class="data row9 col0" >36</td>
#       <td id="T_52b5f_row9_col1" class="data row9 col1" >Nude Aphrodite standing facing, head right, covering her breasts with right hand and pudenda with left hand; to left, Eros, riding a dolphin downwards.</td>
#       <td id="T_52b5f_row9_col2" class="data row9 col2" >[('Aphrodite', 'PERSON', 'standing', 'standing'), ('Aphrodite', 'PERSON', 'holding', 'holding'), ('Eros', 'PERSON', 'seated_on', 'seated_on')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_52b5f_row10_col0" class="data row10 col0" >38</td>
#       <td id="T_52b5f_row10_col1" class="data row10 col1" >Nude Apollo advancing right, holding arrow and drawing bow in his left hand.</td>
#       <td id="T_52b5f_row10_col2" class="data row10 col2" >[('Apollo', 'PERSON', 'advancing', 'advancing'), ('Apollo', 'PERSON', 'holding', 'holding'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_52b5f_row11_col0" class="data row11 col0" >38</td>
#       <td id="T_52b5f_row11_col1" class="data row11 col1" >Nude Apollo advancing right, holding arrow and drawing bow in his left hand.</td>
#       <td id="T_52b5f_row11_col2" class="data row11 col2" >[('Apollo', 'PERSON', 'advancing', 'advancing'), ('Apollo', 'PERSON', 'holding', 'holding'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_52b5f_row12_col0" class="data row12 col0" >38</td>
#       <td id="T_52b5f_row12_col1" class="data row12 col1" >Nude Apollo advancing right, holding arrow and drawing bow in his left hand.</td>
#       <td id="T_52b5f_row12_col2" class="data row12 col2" >[('Apollo', 'PERSON', 'advancing', 'advancing'), ('Apollo', 'PERSON', 'holding', 'holding'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_52b5f_row13_col0" class="data row13 col0" >39</td>
#       <td id="T_52b5f_row13_col1" class="data row13 col1" >Nude Apollo advancing right, wearing fluttering chlamys, drawing arrow in right hand from bow in left hand.</td>
#       <td id="T_52b5f_row13_col2" class="data row13 col2" >[('Apollo', 'PERSON', 'advancing', 'advancing'), ('Apollo', 'PERSON', 'wearing', 'wearing'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_52b5f_row14_col0" class="data row14 col0" >39</td>
#       <td id="T_52b5f_row14_col1" class="data row14 col1" >Nude Apollo advancing right, wearing fluttering chlamys, drawing arrow in right hand from bow in left hand.</td>
#       <td id="T_52b5f_row14_col2" class="data row14 col2" >[('Apollo', 'PERSON', 'advancing', 'advancing'), ('Apollo', 'PERSON', 'wearing', 'wearing'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_52b5f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_52b5f_row15_col0" class="data row15 col0" >39</td>
#       <td id="T_52b5f_row15_col1" class="data row15 col1" >Nude Apollo advancing right, wearing fluttering chlamys, drawing arrow in right hand from bow in left hand.</t

# %%
# duplicate entries for designs are removed (after merge the information is kept in a single row for each design)
X = X.drop_duplicates(['design_id'],keep="first")

# %%
# for preprocessing (preprocessing changes the original design text)
X["design_en_changed"] = ""

# %%
X.shape
# Out:
# (890, 4)

# %%
df_entities = dc.load_from_db("nlp_list_entities", add_columns)

# %%
# Add rules for preprocessing
preprocess = Preprocess()
preprocess.add_rule("horseman", "horse man")
preprocess.add_rule("horsemen", "horse men")

for index, row in df_entities.iterrows():
    if row["alternativenames_en"] is not None:
        if row["class"] != "VERB":
            standard_name = row["name_en"]
            alt_names = row["alternativenames_en"].split(", ")
            for alt_name in alt_names:
                preprocess.add_rule(alt_name, standard_name)

# %% [markdown]
# #### Bei römischen Zahlen scheint es noch kleine Probleme zu geben, daher nochmal extra manuell

# %%
for rule in list(preprocess.rules):
    if " I." in rule or " II." in rule or " III." in rule or " IV." in rule or " V." in rule:
        del preprocess.rules[rule]

# %%
for index, row in X.iterrows():
    if " I." in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace(" I.", " I")
    if " II." in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace(" II.", " II")
    if " III." in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace(" III.", " III")
    if " IV." in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace(" IV.", " IV")
    if " V." in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace(" V.", " V")

# %%
# Deleting brackets and questionmarks

for index, row in X.iterrows():
    if "?" in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace("?", "")
    if "(" in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace("(", "")
    if ")" in row["design_en"]:
        X.at[index, "design_en"] = row["design_en"].replace(")", "")

# %% [markdown]
# ## Apply Preprocessing

# %%
# Apply defined rules
X["design_en_changed"] = X.swifter.apply(lambda row: preprocess.preprocess_design(row.design_en, row.design_id)[0], axis=1)
# Out:
# Pandas Apply: 100%|███████████████████████████| 890/890 [00:17<00:00, 51.33it/s]

# %%
# Deleting brackets and questionmarks
X["design_en_changed"] = X.swifter.apply(lambda row: row["design_en_changed"].replace("?", "").replace("(", "").replace(")", ""), axis=1)
# Out:
# Pandas Apply: 100%|███████████████████████| 890/890 [00:00<00:00, 185459.59it/s]

# %%
X.rename(columns={"design_en":"design_en_orig", "design_en_changed":"design_en", "y":"annotations_orig"}, inplace=True)

# %%
# Mapping GT - prepocessing rules are also applied to GT
X["y"] = X.swifter.apply(lambda row: preprocess.preprocess_re(row["annotations_orig"], row.design_id), axis=1)
# Out:
# Pandas Apply: 100%|███████████████████████| 890/890 [00:00<00:00, 105405.35it/s]

# %% [markdown]
# ### Train the RE model

# %%
# optional - if already defined above
id_col_RE = "design_id"
design_col_RE = "design_en"

# %%
classifier = LogisticRegression(max_iter=1000)
#classifier = RandomForestClassifier()
string_converter = Path2Str(pos=True) 
vectorizer = CountVectorizer(ngram_range=(1,3))
feature = make_pipeline(string_converter, vectorizer)

# %%
X_train, X_test, y_train, y_test = train_test_split(X[[id_col_RE, design_col_RE]], X[[id_col_RE, "y"]], test_size=0.25, random_state=33)

# %%
X.head()
# Out:
#    design_id                                     design_en_orig  \
# 0          9  Amphora with ribbed surface and crooked handle...
# 1         10  Bust of youthful Anchialos, right, wearing tae...
# 2         24  Bare-headed bust of Antoninus Pius, right, wea...
# 3         27  Laureate bust of Antoninus Pius, right, wearin...
# 4         28  Laureate bust of Antoninus Pius, right, wearin...
#
#                                annotations_orig  \
# 0         [(amphora, OBJECT, holding, holding)]
# 1       [(Anchialos, PERSON, wearing, wearing)]
# 2  [(Antoninus Pius, PERSON, wearing, wearing)]
# 3  [(Antoninus Pius, PERSON, wearing, wearing)]
# 4  [(Antoninus Pius, PERSON, wearing, wearing)]
#
#                                            design_en  \
# 0  Amphora with ribbed surface and crooked handle...
# 1  Bust of youthful Anchialos, right, wearing tae...
# 2  Bare-headed bust of Antoninus Pius, right, wea...
# 3  Wreath bust of Antoninus Pius, right, wearing ...
# 4  Wreath bust of Antoninus Pius, right, wearing ...
#
#                                               y
# 0         [(amphora, OBJECT, holding, holding)]
# 1       [(Anchialos, PERSON, wearing, wearing)]
# 2  [(Antoninus Pius, PERSON, wearing, wearing)]
# 3  [(Antoninus Pius, PERSON, wearing, wearing)]
# 4  [(Antoninus Pius, PERSON, wearing, wearing)]

# %%
X.shape
# Out:
# (890, 5)

# %%
X_train
# Out:
#       design_id                                          design_en
# 804         771          Hound seated right; behind, ear of grain.
# 592         615  Griffin lying left, right forepaw raised, with...
# 730         708  Head of Hermes, right, wearing wing petasus; i...
# 1284       2256             Horse prancing right; below, monogram.
# 805       24669  Hygieia and Asclepius; to left, Hygieia standi...
# ...         ...                                                ...
# 1513       5914  Wreath bust of Macrinus, right; wearing scale ...
# 1316       2302  Nude bearded Heracles standing facing, head ri...
# 1657       6081  Athena standing facing, holding spear and shie...
# 864        2394  Head of Athena, right, wearing Attic helmet; w...
# 43        24725  Apollo Bonus Eventus standing facing, head lef...
#
# [667 rows x 2 columns]

# %%
y_train
# Out:
#       design_id                                                  y
# 804         771            [(hound, ANIMAL, seated_on, seated_on)]
# 592         615  [(griffin, ANIMAL, lying, lying), (griffin, AN...
# 730         708               [(Hermes, PERSON, wearing, wearing)]
# 1284       2256              [(horse, ANIMAL, prancing, prancing)]
# 805       24669  [(Hygieia, PERSON, standing, standing), (Hygie...
# ...         ...                                                ...
# 1513       5914             [(Macrinus, PERSON, wearing, wearing)]
# 1316       2302  [(Heracles, PERSON, standing, standing), (Hera...
# 1657       6081  [(Athena, PERSON, standing, standing), (Athena...
# 864        2394               [(Athena, PERSON, wearing, wearing)]
# 43        24725  [(Apollo, PERSON, standing, standing), (Apollo...
#
# [667 rows x 2 columns]

# %% [markdown]
# #### load pretrained NER-Model

# %%
# optional - if already defined above
ner_model_directory = "../cnt/trained_model/ner/english_new_single/"
ner_model_name = "english_cno"

# %% [markdown]
# #### define RE-Model path

# %%
# optional - if already defined above
re_model_directory = "../cnt/trained_model/re_subverb/"
re_model_name = "english_cno"

# %%
# training
inner_pipeline = make_pipeline(feature, classifier)
pipeline = make_pipeline(NERTransformer(ner_model_directory, ner_model_name, id_col_RE, design_col_RE),
                         FeatureExtractor(ner_model_directory, ner_model_name, id_col_RE, design_col_RE),
                         RelationExtractor(inner_pipeline, re_model_directory, re_model_name, id_col_RE))
pipeline.fit(X_train, y_train)
# Out:
# NER(doc=Hound seated right; behind, ear of grain., subj=Hound, verb=seated)
# NER(doc=Griffin lying left, right forepaw raised, with feather wing, tail under hindlegs and closed beak. Ground line., subj=Griffin, verb=lying)
# NER(doc=Griffin lying left, right forepaw raised, with feather wing, tail under hindlegs and closed beak. Ground line., subj=feather, verb=lying)
# NER(doc=Griffin lying left, right forepaw raised, with feather wing, tail under hindlegs and closed beak. Ground line., subj=wing, verb=lying)
# NER(doc=Head of Hermes, right, wearing wing petasus; in front of him caduceus., subj=Head, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus; in front of him caduceus., subj=Hermes, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus; in front of him caduceus., subj=wing, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus; in front of him caduceus., subj=petasus, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus; in front of him caduceus., subj=caduceus, verb=wearing)
# NER(doc=Horse prancing right; below, monogram., subj=Horse, verb=prancing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Hygieia, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=arm, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=arm, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=arm, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=arm, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=patera, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=patera, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=patera, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=patera, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=Asclepius, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=head, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=head, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=head, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=head, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent staff, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent staff, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent staff, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=serpent staff, verb=resting)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=feeding)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=standing)
# NER(doc=Hygieia and Asclepius; to left, Hygieia standing right, feeding serpent held in right arm from patera in outstretched left hand; to right, Asclepius standing facing, head left, resting right hand on serpent staff in right hand., subj=hand, verb=resting)
# NER(doc=Head of Hermes, right, wearing wing petasus., subj=Head, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus., subj=Hermes, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus., subj=wing, verb=wearing)
# NER(doc=Head of Hermes, right, wearing wing petasus., subj=petasus, verb=wearing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=Dionysus, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=Dionysus, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=Dionysus, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=head, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=head, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=head, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=shoulder, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=shoulder, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=shoulder, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=cantharus, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=cantharus, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=cantharus, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=hand, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=hand, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=hand, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=panther, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=panther, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=panther, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=head, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=head, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=head, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=thyrsus, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=thyrsus, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=thyrsus, verb=seated)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=arm, verb=standing)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=arm, verb=holding)
# NER(doc=Nude youthful Dionysus standing facing, head left, nebris over left shoulder to right hip, holding cantharus in right hand over panther seated left, head right, and filleted thyrsus in left arm. Ground line. Border of dots., subj=arm, verb=seated)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=Cybele, verb=reclining)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=Cybele, verb=advancing)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=Cybele, verb=holding)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=lion, verb=reclining)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=lion, verb=advancing)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=lion, verb=holding)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=object, verb=reclining)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=object, verb=advancing)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=object, verb=holding)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=hand, verb=reclining)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=hand, verb=advancing)
# NER(doc=Cybele reclining left on lion advancing right, holding uncertain object in right hand., subj=hand, verb=holding)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=Heracles, verb=standing)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=Heracles, verb=resting)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=Heracles, verb=holding)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=arm, verb=standing)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=arm, verb=resting)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=arm, verb=holding)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=club, verb=standing)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=club, verb=resting)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=club, verb=holding)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=lion skin, verb=standing)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=lion skin, verb=resting)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=lion skin, verb=holding)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=bow, verb=standing)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=bow, verb=resting)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=bow, verb=holding)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=arm, verb=standing)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=arm, verb=resting)
# NER(doc=Nude Heracles standing right, resting right arm on club, holding lion skin and bow in left arm. Ground line., subj=arm, verb=holding)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=Apollo, verb=standing)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=Apollo, verb=holding)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=patera, verb=standing)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=patera, verb=holding)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=altar, verb=standing)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=altar, verb=holding)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=hand, verb=standing)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=hand, verb=holding)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=bow, verb=standing)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=bow, verb=holding)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=hand, verb=standing)
# NER(doc=Nude Apollo standing left, holding patera over lighted altar in right hand and bow in left hand., subj=hand, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=Dionysus, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=Dionysus, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=Dionysus, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=head, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=head, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=head, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=boot, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=boot, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=boot, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=cantharus, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=cantharus, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=cantharus, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=hand, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=hand, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=hand, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=thyrsus, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=thyrsus, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=thyrsus, verb=holding)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=arm, verb=standing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=arm, verb=wearing)
# NER(doc=Nude Dionysus standing facing, head left, wearing boot, holding cantharus in right hand and pelleted and filleted thyrsus in left arm., subj=arm, verb=holding)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=Heracles, verb=seated)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=Heracles, verb=resting)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=rock, verb=seated)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=rock, verb=resting)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=hand, verb=seated)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=hand, verb=resting)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=rock, verb=seated)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=rock, verb=resting)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=club, verb=seated)
# NER(doc=Nude Heracles seated left on rock, his right hand outstretched, left resting on rock; in front, upright club., subj=club, verb=resting)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=veil, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=veil, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=veil, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=veil, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Demeter, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=diadem, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=diadem, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=diadem, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=diadem, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=Kore, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=holding)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=standing)
# NER(doc=Confroted Demeter and Kore; to right, veil Demeter standing left, holding torch and two corn; to left, diadem Kore standing right, holding torch and poppy ., subj=torch, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=Heracles, verb=standing)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=Heracles, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=Heracles, verb=resting)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=arm, verb=standing)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=arm, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=arm, verb=resting)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=arm, verb=standing)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=arm, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=arm, verb=resting)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=lion skin, verb=standing)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=lion skin, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=lion skin, verb=resting)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=club, verb=standing)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=club, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=club, verb=resting)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=rock, verb=standing)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=rock, verb=holding)
# NER(doc=Nude bearded Heracles standing right, right arm behind back, left arm holding lion skin and resting on club set on rock. Border of dots., subj=rock, verb=resting)
# NER(doc=Horse standing left., subj=Horse, verb=standing)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=Athena, verb=standing)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=Athena, verb=holding)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=patera, verb=standing)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=patera, verb=holding)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=shield, verb=standing)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=shield, verb=holding)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=foot, verb=standing)
# NER(doc=Athena standing left, holding patera and shield set down at her foot., subj=foot, verb=holding)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=Heracles, verb=standing)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=Heracles, verb=holding)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=hand, verb=standing)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=hand, verb=holding)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=club, verb=standing)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=club, verb=holding)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=lion skin, verb=standing)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=lion skin, verb=holding)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=arm, verb=standing)
# NER(doc=Nude Heracles standing left, holding apple in right hand, club and lion skin in left arm., subj=arm, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=Emperor, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=Emperor, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=Emperor, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=Gordian, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=Gordian, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=Gordian, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=military attire, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=military attire, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=military attire, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=horse, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=horse, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=horse, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=cuirass, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=cuirass, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=cuirass, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=paludamentum, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=paludamentum, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=paludamentum, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=spear, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=spear, verb=wearing)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=spear, verb=holding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=hand, verb=riding)
# NER(doc=Emperor Gordian in military attire riding right on horse, wearing cuirass and fluttering paludamentum, holding spear in right hand towards a captive in front of him., subj=hand, verb=wearing)
# ...
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=arm, verb=crowning)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=arm, verb=resting)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=shield, verb=holding)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=shield, verb=crowning)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=shield, verb=resting)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=spear, verb=holding)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=spear, verb=crowning)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=spear, verb=resting)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=lion, verb=holding)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=lion, verb=crowning)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=lion, verb=resting)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=head, verb=holding)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=head, verb=crowning)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=head, verb=resting)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=throne, verb=holding)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=throne, verb=crowning)
# NER(doc=Athena Nikephoros throne left, holding Nike, crowning the king's name, in outstretched right hand; left arm resting on shield behind; in background, transverse spear; in inner left field, lion's head, left; on throne monogram., subj=throne, verb=resting)
# NER(doc=Eros standing right, legs crossed, resting on anchor., subj=Eros, verb=standing)
# NER(doc=Eros standing right, legs crossed, resting on anchor., subj=Eros, verb=resting)
# NER(doc=Eros standing right, legs crossed, resting on anchor., subj=anchor, verb=standing)
# NER(doc=Eros standing right, legs crossed, resting on anchor., subj=anchor, verb=resting)
# NER(doc=Wreath bust of Macrinus, right; wearing scale cuirass and paludamentum., subj=Wreath, verb=wearing)
# NER(doc=Wreath bust of Macrinus, right; wearing scale cuirass and paludamentum., subj=bust, verb=wearing)
# NER(doc=Wreath bust of Macrinus, right; wearing scale cuirass and paludamentum., subj=Macrinus, verb=wearing)
# NER(doc=Wreath bust of Macrinus, right; wearing scale cuirass and paludamentum., subj=scale cuirass, verb=wearing)
# NER(doc=Wreath bust of Macrinus, right; wearing scale cuirass and paludamentum., subj=paludamentum, verb=wearing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=Heracles, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=Heracles, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=Heracles, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=head, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=head, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=head, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=lion skin, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=lion skin, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=lion skin, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=shoulder, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=shoulder, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=shoulder, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=club, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=club, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=club, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=hand, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=hand, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=hand, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=shoulder, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=shoulder, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=shoulder, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=Cerberus, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=Cerberus, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=Cerberus, verb=drawing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=leash, verb=standing)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=leash, verb=holding)
# NER(doc=Nude bearded Heracles standing facing, head right, lion skin over shoulder, holding club with right hand over shoulder; drawing out Cerberus on a leash., subj=leash, verb=drawing)
# NER(doc=Athena standing facing, holding spear and shield; all within incuse square., subj=Athena, verb=standing)
# NER(doc=Athena standing facing, holding spear and shield; all within incuse square., subj=Athena, verb=holding)
# NER(doc=Athena standing facing, holding spear and shield; all within incuse square., subj=spear, verb=standing)
# NER(doc=Athena standing facing, holding spear and shield; all within incuse square., subj=spear, verb=holding)
# NER(doc=Athena standing facing, holding spear and shield; all within incuse square., subj=shield, verb=standing)
# NER(doc=Athena standing facing, holding spear and shield; all within incuse square., subj=shield, verb=holding)
# NER(doc=Head of Athena, right, wearing Attic helmet; within incuse square., subj=Head, verb=wearing)
# NER(doc=Head of Athena, right, wearing Attic helmet; within incuse square., subj=Athena, verb=wearing)
# NER(doc=Head of Athena, right, wearing Attic helmet; within incuse square., subj=helmet, verb=wearing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=Apollo, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=Apollo, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=Bonus Eventus, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=Bonus Eventus, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=head, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=head, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=patera, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=patera, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=hand, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=hand, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=altar, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=altar, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=laurel branch, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=laurel branch, verb=holding)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=hand, verb=standing)
# NER(doc=Apollo Bonus Eventus standing facing, head left, holding patera in outstretched right hand over lighted altar and laurel branch in left hand., subj=hand, verb=holding)
# Pipeline(steps=[('nertransformer',
#                  NERTransformer(design_col='design_en', id_col='design_id',
#                                 model_dir='../cnt/trained_model/ner/english_new_single/',
#                                 model_name='english_cno')),
#                 ('featureextractor',
#                  FeatureExtractor(design_col='design_en', id_col='design_id',
#                                   model_dir='../cnt/trained_model/ner/english_new_single/',
#                                   model_name='english_cno')),
#                 ('relationextractor',
#                  RelationExtractor(id_col='design_id', model_name='english_cno',
#                                    output_dir='../cnt/trained_model/re_subverb/',
#                                    pipeline=Pipeline(steps=[('pipeline',
#                                                              Pipeline(steps=[('path2str',
#                                                                               Path2Str(pos=True)),
#                                                                              ('countvectorizer',
#                                                                               CountVectorizer(ngram_range=(1,
#                                                                                                            3)))])),
#                                                             ('logisticregression',
#                                                              LogisticRegression(max_iter=1000))])))])

# %% [markdown]
# ## Save and Load model

# %%
save_pipeline(pipeline, re_model_directory, re_model_name)

# %%
model = load_pipeline(re_model_directory, re_model_name)

# %% [markdown]
# ## Predict

# %%
y_pred = model.predict(X_test)

# %%
metrics = Metrics()

# %%
precision, recall = metrics.score_precision_recall(y_test, y_pred)
F1 = (2*precision*recall) / (precision + recall)

# %%
print("Precision", round(precision*100,2))
print("Recall", round(recall*100,2))
print("F1", round(F1*100,2))
# Out:
# Precision 93.06
# Recall 56.07
# F1 69.97

# %% [markdown]
# ## Map back

# %%
# results (that are based on the preprocessed designs) are mapped back to the original designs

X_test["y"] = y_test["y"]

# %%
# Deleting brackets and questionmarks
X_test["y_mapped"] = X_test.swifter.apply(lambda row: preprocess.map_re(row["y"], row.design_id), axis=1)
# Out:
# Pandas Apply: 100%|████████████████████████| 223/223 [00:00<00:00, 45439.65it/s]

# %%
X_test.head(5).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_97411">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97411_level0_col0" class="col_heading level0 col0" >design_id</th>
#       <th id="T_97411_level0_col1" class="col_heading level0 col1" >design_en</th>
#       <th id="T_97411_level0_col2" class="col_heading level0 col2" >y</th>
#       <th id="T_97411_level0_col3" class="col_heading level0 col3" >y_mapped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97411_level0_row0" class="row_heading level0 row0" >690</th>
#       <td id="T_97411_row0_col0" class="data row0 col0" >675</td>
#       <td id="T_97411_row0_col1" class="data row0 col1" >Nude Heracles Farnese standing left, leaning on club with right hand set on rock, left hand on hip; lion skin over club.</td>
#       <td id="T_97411_row0_col2" class="data row0 col2" >[('Heracles', 'PERSON', 'standing', 'standing'), ('Heracles', 'PERSON', 'resting_on', 'resting_on')]</td>
#       <td id="T_97411_row0_col3" class="data row0 col3" >[('Heracles', 'PERSON', 'standing', 'standing'), ('Heracles', 'PERSON', 'resting_on', 'resting_on')]</td>
#     </tr>
#     <tr>
#       <th id="T_97411_level0_row1" class="row_heading level0 row1" >181</th>
#       <td id="T_97411_row1_col0" class="data row1 col0" >219</td>
#       <td id="T_97411_row1_col1" class="data row1 col1" >Head of bearded Byzas, right, wearing crested helmet with open visor. Border of dots.</td>
#       <td id="T_97411_row1_col2" class="data row1 col2" >[('Byzas', 'PERSON', 'wearing', 'wearing')]</td>
#       <td id="T_97411_row1_col3" class="data row1 col3" >[('Byzas', 'PERSON', 'wearing', 'wearing')]</td>
#     </tr>
#     <tr>
#       <th id="T_97411_level0_row2" class="row_heading level0 row2" >1346</th>
#       <td id="T_97411_row2_col0" class="data row2 col0" >2323</td>
#       <td id="T_97411_row2_col1" class="data row2 col1" >Nude Heracles sitting left on rock, his right hand outstretched, left resting on rock; at left, half-naked nymph standing facing, head right, holding a bow in both hand.</td>
#       <td id="T_97411_row2_col2" class="data row2 col2" >[('Heracles', 'PERSON', 'seated_on', 'seated_on'), ('Heracles', 'PERSON', 'resting_on', 'resting_on'), ('nymph', 'PERSON', 'standing', 'standing'), ('nymph', 'PERSON', 'holding', 'holding')]</td>
#       <td id="T_97411_row2_col3" class="data row2 col3" >[('Heracles', 'PERSON', 'seated_on', 'seated_on'), ('Heracles', 'PERSON', 'resting_on', 'resting_on'), ('nymph', 'PERSON', 'standing', 'standing'), ('nymph', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_97411_level0_row3" class="row_heading level0 row3" >692</th>
#       <td id="T_97411_row3_col0" class="data row3 col0" >676</td>
#       <td id="T_97411_row3_col1" class="data row3 col1" >Nude Heracles standing facing, head left, resting right hand on club, left hand on hip, holding lion skin in left arm.</td>
#       <td id="T_97411_row3_col2" class="data row3 col2" >[('Heracles', 'PERSON', 'standing', 'standing'), ('Heracles', 'PERSON', 'resting_on', 'resting_on'), ('Heracles', 'PERSON', 'holding', 'holding')]</td>
#       <td id="T_97411_row3_col3" class="data row3 col3" >[('Heracles', 'PERSON', 'standing', 'standing'), ('Heracles', 'PERSON', 'resting_on', 'resting_on'), ('Heracles', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#     <tr>
#       <th id="T_97411_level0_row4" class="row_heading level0 row4" >47</th>
#       <td id="T_97411_row4_col0" class="data row4 col0" >24726</td>
#       <td id="T_97411_row4_col1" class="data row4 col1" >Nude Apollo standing left, holding patera in outstretched right hand over altar and laurel branch in left hand.</td>
#       <td id="T_97411_row4_col2" class="data row4 col2" >[('Apollo', 'PERSON', 'standing', 'standing'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#       <td id="T_97411_row4_col3" class="data row4 col3" >[('Apollo', 'PERSON', 'standing', 'standing'), ('Apollo', 'PERSON', 'holding', 'holding')]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Auto relations

# %%
# adding relations based on adjectives - experimental
obj_list = {
"veiled": ("wearing", "Veil", "before"),
"draped": ("wearing", "Clothing", "before"),
"helmeted": ("wearing", "Helmet", "before"),
"diademed": ("wearing", "Diadem", "before"),
"turreted": ("wearing", "Mural crown", "before"),
"enthroned": ("seated_on", "Throne", "after"),

}

# %%
y_pred["design_en"] = X_test.design_en

# %%
y_pred = relations_from_adjectives_df(y_pred, "design_en", "y", ner_model_directory, ner_model_name, id_col, design_col, obj_list, entities_to_consider=["PERSON"])

# %%
y_pred
# Out:
#       design_id                                                  y  \
# 690         675                                                 []
# 181         219                                                 []
# 1346       2323                                                 []
# 692         676                                                 []
# 47        24726                                                 []
# ...         ...                                                ...
# 1845       6250                                                 []
# 1362       2332                                                 []
# 134         144                 [(Athena, PERSON, throne, throne)]
# 192         236                                                 []
# 264         323  [(Tower, OBJECT, throne, throne), (Cybele, PER...
#
#                                               design_en
# 690   Nude Heracles Farnese standing left, leaning o...
# 181   Head of bearded Byzas, right, wearing crested ...
# 1346  Nude Heracles sitting left on rock, his right ...
# 692   Nude Heracles standing facing, head left, rest...
# 47    Nude Apollo standing left, holding patera in o...
# ...                                                 ...
# 1845  Artemis standing facing, holding torch in both...
# 1362  Griffin seated left, right forepaw raised, wit...
# 134   Athena Nikephoros throne left, holding Nike in...
# 192   Capricorn standing right; above, cornucopia. B...
# 264   Tower Cybele throne left, holding patera in ou...
#
# [223 rows x 3 columns]

# %%
# for testing a single design

design = "Diademed Athena to the left and helmeted Ares to the right, holding sword."
# rule based - see above 
auto_relations = relations_from_adjectives_single(design,ner_model_directory, ner_model_name, id_col_RE, design_col_RE, obj_list)
# results of the model
model_relations = predict_re_single_sentence(model, design, id_col_RE, design_col_RE)
# merging both results
concat_relations(auto_relations, model_relations)
# Out:
# [('Ares', 'PERSON', 'wearing', 'Helmet', 'OBJECT'),
#  ('Athena', 'PERSON', 'wearing', 'Diadem', 'OBJECT'),
#  ('Athena', 'PERSON', 'holding', 'sword', 'OBJECT'),
#  ('Ares', 'PERSON', 'holding', 'sword', 'OBJECT')]

# %%
# optional -only if results need to be uploaded to database
# preprocessing
upload = True
f = open("/home/bigdatalab/Projects/D4N4/NLP_release_1.0/db_access.txt", "r")
access = f.read()
dc =  Database_Connection(access)
cnt_designs = dc.load_designs_from_db("data_designs", [id_col, design_col])
cnt_designs = cnt_designs.rename(columns={"id": "design_id"})

cnt_designs["design_en_changed"] = cnt_designs.swifter.apply(lambda row: preprocess.preprocess_design(row.design_en, row.design_id)[0], axis=1)
cnt_designs["design_en_changed"] = cnt_designs.swifter.apply(lambda row: row["design_en_changed"].replace("?", "").replace("(", "").replace(")", ""), axis=1)
# Out:
# Pandas Apply: 100%|█████████████████████████| 7759/7759 [02:27<00:00, 52.76it/s]
# Pandas Apply: 100%|█████████████████████| 7759/7759 [00:00<00:00, 207181.18it/s]

# %%
# optional -only if results need to be uploaded to database
cnt_designs = cnt_designs.rename(columns={"design_en": "design_en_org"})
cnt_designs = cnt_designs.rename(columns={"design_en_changed": "design_en"})

# %%
# optional -only if results need to be uploaded to database - TODO: check by Sebastian on BDL-Server
upload = True
if upload ==True:
    cnt_pred = model.predict(cnt_designs, rdf=True)
    cnt_pipeline_output = pd.DataFrame([(str(designid), *relation) for  _, (designid, relation_list) in cnt_pred.iterrows()
                    for relation in relation_list],
            columns=["DesignID", "Person", "Label_Person", "Relation", "Object"])
    cnt_pipeline_output.to_sql("cnt_pipeline_output_v3",dc.mysql_connection,if_exists="replace", index=False)

# %%
cnt_designs.head()
# Out:
#    design_id                                      design_en_org  \
# 0          1  Diademed head of deified Alexander the Great w...
# 1          6                      Altar, lighted and garlanded.
# 2          8  Prize amphora on ornamental stand; within line...
# 3          9  Amphora with ribbed surface and crooked handle...
# 4         10  Bust of youthful Anchialos, right, wearing tae...
#
#                                            design_en
# 0  Diadem head of deified Alexander the Great wit...
# 1                        Altar, lighted and garland.
# 2  Prize amphora on ornamental stand; within line...
# 3  Amphora with ribbed surface and crooked handle...
# 4  Bust of youthful Anchialos, right, wearing tae...

# %%
cnt_pipeline_output = pd.DataFrame([(str(designid), *relation) for  _, (designid, relation_list) in cnt_pred.iterrows()
                    for relation in relation_list], columns=["DesignID", "Person", "Label_Person", "Relation", "Object"])
cnt_pipeline_output.to_sql("cnt_pipeline_output_v3",dc.mysql_connection,if_exists="replace", index=False)
# Out:
# 9119
