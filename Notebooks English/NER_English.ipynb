# %% [markdown]
# developed by Patricia Klinger, modified by Sebastian Gampe, Kerim Gencer, Chrisowalandis Deligio

# %%
import sys
sys.path.append('../')
import pandas as pd
import random
import os
import numpy as np
from cnt.model import DesignEstimator, save_ner_model, load_ner_model,save_ner_model_v2, load_ner_model_v2
from cnt.annotate import (annotate, annotate_single_design, 
                          annotate_designs, 
                          extract_string_from_annotation, split_alternativenames)
from cnt.evaluate import Metrics
#from cnt.stem_lemma_annotation import Stem_Lemma_Annotatizer
from cnt.preprocess import Preprocess
import spacy
from cnt.io import  Database_Connection
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define the column names for the id and design column

# %%
id_col = "id"
design_col = "design_en"
use_lemma_stem = False

# %%
dc =  Database_Connection("mysql+mysqlconnector://root:YourConnection") # Format user:password@IP/Database

# %%
designs = dc.load_designs_from_db("nlp_training_designs", [id_col, design_col, "comment"])

# %%
designs
# Out:
#           id                                          design_en  \
# 0          1  Diademed head of deified Alexander the Great w...
# 1          6                      Altar, lighted and garlanded.
# 2          8  Prize amphora on ornamental stand; within line...
# 3          9  Amphora with ribbed surface and crooked handle...
# 4         10  Bust of youthful Anchialos, right, wearing tae...
# ...      ...                                                ...
# 22559  27814                    Seleucus I wearing crown juwel.
# 22560  27815                          Athena seated on dolphin.
# 22561  27816               Rhoemetalces I holding paludamentum.
# 22562  27817                            Equitas seated on bull.
# 22563  27818                                Nike holding sword.
#
#               comment
# 0             from CN
# 1             from CN
# 2             from CN
# 3             from CN
# 4             from CN
# ...               ...
# 22559  auto_generated
# 22560  auto_generated
# 22561  auto_generated
# 22562  auto_generated
# 22563  auto_generated
#
# [22564 rows x 3 columns]

# %%
designs.head(5)
# Out:
#    id                                          design_en  comment
# 0   1  Diademed head of deified Alexander the Great w...  from CN
# 1   6                      Altar, lighted and garlanded.  from CN
# 2   8  Prize amphora on ornamental stand; within line...  from CN
# 3   9  Amphora with ribbed surface and crooked handle...  from CN
# 4  10  Bust of youthful Anchialos, right, wearing tae...  from CN

# %% [markdown]
# ## This step is optional - load additional data to save with the model

# %% [raw]
# language = "_en"
# add_columns = ["name"+language, "alternativenames"+language, "link"]

# %% [raw]
# entity_information = [dc.load_designs_from_db("nlp_list_person", ["name", "alternativenames", "link"]),
#                       dc.load_designs_from_db("nlp_list_obj", add_columns),
#                       dc.load_designs_from_db("nlp_list_animal", add_columns),
#                       dc.load_designs_from_db("nlp_list_plant", add_columns)]

# %% [raw]
# for dataframe in entity_information:
#     dataframe.rename(columns={"name"+language:"name", "alternativenames"+language:"alternativenames"}, inplace=True)

# %% [raw]
# optional_info = pd.DataFrame(columns=["name","link"])
# for df in entity_information:
#     tmp = split_alternativenames(df.fillna(" "))
#     optional_info = optional_info.append(tmp)

# %% [raw]
# optional_info.head(5)

# %% [raw]
# optional_info.shape

# %% [raw]
# optional_info.loc[optional_info["name"]=="Andromeda"]["link"].item()

# %% [markdown]
# ## Load and annotate designs

# %%
language = "_en"
add_columns = ["name"+language, "alternativenames"+language]

# %%
entities = {
    "PERSON": dc.load_entities_from_db("nlp_list_person", ["name", "alternativenames"], ["alternativenames"], ",", True),
    "OBJECT": dc.load_entities_from_db("nlp_list_obj", add_columns, [add_columns[1]], ",", True),
    "ANIMAL": dc.load_entities_from_db("nlp_list_animal", add_columns, [add_columns[1]], ",", True),
    "PLANT": dc.load_entities_from_db("nlp_list_plant", add_columns, [add_columns[1]], ",", True)}

# %%
annotated_designs = annotate_designs(entities, designs, id_col, design_col)
annotated_designs = annotated_designs[
    annotated_designs.annotations.map(len) > 0]

# %%
if use_lemma_stem:
    annotater = Stem_Lemma_Annotatizer() # parameter: method="lemma_stem", language="en", backbone="spacy_snowball"
    annotated_designs = annotater.annotate(annotated_designs, entities, id_col, design_col)

# %%
annotated_designs.head(5)
# Out:
#                                            design_en  id  \
# 0  Diademed head of deified Alexander the Great w...   1
# 1                      Altar, lighted and garlanded.   6
# 2  Prize amphora on ornamental stand; within line...   8
# 3  Amphora with ribbed surface and crooked handle...   9
# 4  Bust of youthful Anchialos, right, wearing tae...  10
#
#                                          annotations
# 0  [(0, 8, OBJECT), (9, 13, OBJECT), (25, 44, PER...
# 1                 [(0, 5, OBJECT), (19, 28, OBJECT)]
# 2                                  [(6, 13, OBJECT)]
# 3  [(0, 7, OBJECT), (40, 47, OBJECT), (63, 75, PL...
# 4  [(0, 4, OBJECT), (17, 26, PERSON), (43, 49, OB...

# %%
annotated_designs.shape
# Out:
# (22396, 3)

# %% [markdown]
# ## Train NER

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(annotated_designs[[id_col, design_col]],
                                                    annotated_designs[[id_col, "annotations"]],
                                                    test_size=0.25, random_state = 12)
y_test = y_test.rename(columns={"annotations": "y"})

# %%
X_test.index = [i for i in range(X_test.shape[0])]
y_test.index = [i for i in range(y_test.shape[0])]

# %% [markdown]
# #### output directory for the trained model

# %%
output_dir =  "../cnt/trained_model/ner/english/"
model_name = "english_cno"

# %%
my_estimator = DesignEstimator(4, output_dir, model_name, id_col, design_col)
my_estimator.set_labels("PERSON", "OBJECT", "ANIMAL", "PLANT")
my_estimator.fit(X_train, y_train.annotations, "cnt")
# Out:
# ../cnt/trained_model/ner/english
# Saved model to ../cnt/trained_model/ner/english

# %% [markdown]
# ## Load and evaluate model

# %%
model = load_ner_model_v2(output_dir, model_name, id_col, design_col)

# %%
x_predict = model.predict(X_test,as_doc=False)

# %%
x_predict
# Out:
#          id                                                  y
# 0     17740  [(10, 16, OBJECT), (18, 27, OBJECT), (53, 61, ...
# 1     13637  [(0, 9, PERSON), (14, 18, PERSON), (28, 43, OB...
# 2     23165  [(0, 6, OBJECT), (37, 43, OBJECT), (49, 54, OB...
# 3     12962  [(0, 4, OBJECT), (8, 14, PERSON), (16, 23, OBJ...
# 4     15046  [(0, 10, PERSON), (12, 18, OBJECT), (38, 46, O...
# ...     ...                                                ...
# 5594     82  [(5, 11, PERSON), (35, 41, OBJECT), (64, 68, O...
# 5595  10838  [(0, 4, OBJECT), (8, 22, PERSON), (37, 43, OBJ...
# 5596   4378  [(0, 7, PERSON), (9, 26, PERSON), (31, 46, OBJ...
# 5597  14639  [(0, 14, PERSON), (20, 28, PERSON), (30, 38, O...
# 5598   7271  [(0, 15, PERSON), (20, 31, PERSON), (66, 71, O...
#
# [5599 rows x 2 columns]

# %%
metrics = Metrics()

# %%
scores_frame = metrics.create_score_frame(y_test, x_predict, my_estimator.get_labels())
scores_frame
# Out:
#            Total(TP+FN)  Hits(TP)  Wrongs(FP)     %
# 0  PERSON          6122      6097          39  99.6
# 1  OBJECT         22978     22949          62  99.9
# 2  ANIMAL          1268      1254           4  98.9
# 3   PLANT           939       933           9  99.4

# %%
precision, recall = metrics.score_precision_recall(y_test, x_predict)

# %%
F1 = (2*precision*recall) / (precision + recall)

# %%
print("Precision", round(precision*100,2))
print("Recall", round(recall*100,2))
print("F1", round(F1*100,2))
# Out:
# Precision 99.64
# Recall 99.76
# F1 99.7

# %% [markdown]
# ## Testset

# %%
y_test.head(5)

# %%
x_predict.head(5)
# Out:
#       id                                                  y
# 0  17740  [(10, 16, OBJECT), (18, 27, OBJECT), (53, 61, ...
# 1  13637  [(0, 9, PERSON), (14, 18, PERSON), (28, 43, OB...
# 2  23165  [(0, 6, OBJECT), (37, 43, OBJECT), (49, 54, OB...
# 3  12962  [(0, 4, OBJECT), (8, 14, PERSON), (16, 23, OBJ...
# 4  15046  [(0, 10, PERSON), (12, 18, OBJECT), (38, 46, O...

# %%
X_test["annotation"] = y_test["y"]
X_test["prediction"] = x_predict["y"]
X_test.head(2)
# Out:
#       id                                          design_en  \
# 0  17740  Johannes, draped, cuirassed, standing right, h...
# 1  13637  Caracalla and Geta, both in military attire, s...
#
#                                           annotation  \
# 0  [(10, 16, OBJECT), (18, 27, OBJECT), (53, 61, ...
# 1  [(0, 9, PERSON), (14, 18, PERSON), (28, 43, OB...
#
#                                           prediction
# 0  [(10, 16, OBJECT), (18, 27, OBJECT), (53, 61, ...
# 1  [(0, 9, PERSON), (14, 18, PERSON), (28, 43, OB...

# %%
def get_text(design, ent_list):
    result = []
    for i in ent_list:
        result.append(design[i[0]:i[1]])
    return result

# %%
X_test["annotation_str"] = X_test.apply(lambda row: get_text(row.design_en, row.annotation), axis=1)
X_test["prediction_str"] = X_test.apply(lambda row: get_text(row.design_en, row.prediction), axis=1)

# %%
X_test.head(2)
# Out:
#       id                                          design_en  \
# 0  17740  Johannes, draped, cuirassed, standing right, h...
# 1  13637  Caracalla and Geta, both in military attire, s...
#
#                                           annotation  \
# 0  [(10, 16, OBJECT), (18, 27, OBJECT), (53, 61, ...
# 1  [(0, 9, PERSON), (14, 18, PERSON), (28, 43, OB...
#
#                                           prediction  \
# 0  [(10, 16, OBJECT), (18, 27, OBJECT), (53, 61, ...
# 1  [(0, 9, PERSON), (14, 18, PERSON), (28, 43, OB...
#
#                                       annotation_str  \
# 0  [draped, cuirassed, standard, hand, Victory, g...
# 1  [Caracalla, Geta, military attire, hands, spea...
#
#                                       prediction_str
# 0  [draped, cuirassed, standard, hand, Victory, g...
# 1  [Caracalla, Geta, military attire, hands, spea...

# %%
X_train["annotation"] = y_train["annotations"]

# %%
X_train["annotation_str"] = X_train.apply(lambda row: get_text(row.design_en, row.annotation), axis=1)

# %%
labels = {}
for index, row in X_test.iterrows():
    for i in row.annotation_str:
        labels[i] = [0,0,0]

for index, row in X_train.iterrows():
    for i in row.annotation_str:
        labels[i] = [0,0,0]

# %%
for index, row in X_test.iterrows():
    annot = row.annotation_str
    pred = row.prediction_str
    
    for i in annot:
        labels[i][0] += 1
        if i in pred:
            labels[i][1] += 1

# %%
for index, row in X_train.iterrows():
    annot = row.annotation_str
    
    for i in annot:
        labels[i][2] += 1

# %%
label_scores = pd.DataFrame().from_dict(labels, orient="index").rename(columns={0:"Annotation", 1:"Prediction", 2:"Total_in_train"})

# %%
label_scores["Accuracy"] = label_scores.apply(lambda row: row.Prediction/row.Annotation, axis=1)

# %%
label_scores.loc[label_scores.index.str.contains("Alexander")]
# Out:
#                      Annotation  Prediction  Total_in_train  Accuracy
# Severus Alexander            31          31             130       1.0
# Domitius Alexander            1           1               3       1.0
# Alexander the Great           1           1               4       1.0

# %%
label_scores.sort_values("Accuracy").head(200).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_77b8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77b8d_level0_col0" class="col_heading level0 col0" >Annotation</th>
#       <th id="T_77b8d_level0_col1" class="col_heading level0 col1" >Prediction</th>
#       <th id="T_77b8d_level0_col2" class="col_heading level0 col2" >Total_in_train</th>
#       <th id="T_77b8d_level0_col3" class="col_heading level0 col3" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77b8d_level0_row0" class="row_heading level0 row0" >Faustina II </th>
#       <td id="T_77b8d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_77b8d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_77b8d_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_77b8d_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row1" class="row_heading level0 row1" >Seleucus I Nikator</th>
#       <td id="T_77b8d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_77b8d_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_77b8d_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_77b8d_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row2" class="row_heading level0 row2" >Consul</th>
#       <td id="T_77b8d_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_77b8d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_77b8d_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_77b8d_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row3" class="row_heading level0 row3" >City wall</th>
#       <td id="T_77b8d_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_77b8d_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_77b8d_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_77b8d_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row4" class="row_heading level0 row4" >aquilae</th>
#       <td id="T_77b8d_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_77b8d_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_77b8d_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_77b8d_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row5" class="row_heading level0 row5" >barley</th>
#       <td id="T_77b8d_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_77b8d_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_77b8d_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_77b8d_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row6" class="row_heading level0 row6" >donkey</th>
#       <td id="T_77b8d_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_77b8d_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_77b8d_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_77b8d_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row7" class="row_heading level0 row7" >rudders</th>
#       <td id="T_77b8d_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_77b8d_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_77b8d_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_77b8d_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row8" class="row_heading level0 row8" >goats</th>
#       <td id="T_77b8d_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_77b8d_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_77b8d_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_77b8d_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row9" class="row_heading level0 row9" >octopus</th>
#       <td id="T_77b8d_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_77b8d_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_77b8d_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_77b8d_row9_col3" class="data row9 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row10" class="row_heading level0 row10" >companion</th>
#       <td id="T_77b8d_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_77b8d_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_77b8d_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_77b8d_row10_col3" class="data row10 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row11" class="row_heading level0 row11" >thunderbolts</th>
#       <td id="T_77b8d_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_77b8d_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_77b8d_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_77b8d_row11_col3" class="data row11 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row12" class="row_heading level0 row12" >Tempus</th>
#       <td id="T_77b8d_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_77b8d_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_77b8d_row12_col2" class="data row12 col2" >0</td>
#       <td id="T_77b8d_row12_col3" class="data row12 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row13" class="row_heading level0 row13" >Savus</th>
#       <td id="T_77b8d_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_77b8d_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_77b8d_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_77b8d_row13_col3" class="data row13 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row14" class="row_heading level0 row14" >bukephalion</th>
#       <td id="T_77b8d_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_77b8d_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_77b8d_row14_col2" class="data row14 col2" >0</td>
#       <td id="T_77b8d_row14_col3" class="data row14 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row15" class="row_heading level0 row15" >Kotys</th>
#       <td id="T_77b8d_row15_col0" class="data row15 col0" >1</td>
#       <td id="T_77b8d_row15_col1" class="data row15 col1" >0</td>
#       <td id="T_77b8d_row15_col2" class="data row15 col2" >3</td>
#       <td id="T_77b8d_row15_col3" class="data row15 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row16" class="row_heading level0 row16" >visor</th>
#       <td id="T_77b8d_row16_col0" class="data row16 col0" >1</td>
#       <td id="T_77b8d_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_77b8d_row16_col2" class="data row16 col2" >0</td>
#       <td id="T_77b8d_row16_col3" class="data row16 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row17" class="row_heading level0 row17" >shells</th>
#       <td id="T_77b8d_row17_col0" class="data row17 col0" >1</td>
#       <td id="T_77b8d_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_77b8d_row17_col2" class="data row17 col2" >0</td>
#       <td id="T_77b8d_row17_col3" class="data row17 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row18" class="row_heading level0 row18" >Nerva Divus</th>
#       <td id="T_77b8d_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_77b8d_row18_col1" class="data row18 col1" >0</td>
#       <td id="T_77b8d_row18_col2" class="data row18 col2" >0</td>
#       <td id="T_77b8d_row18_col3" class="data row18 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row19" class="row_heading level0 row19" >plumed</th>
#       <td id="T_77b8d_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_77b8d_row19_col1" class="data row19 col1" >0</td>
#       <td id="T_77b8d_row19_col2" class="data row19 col2" >0</td>
#       <td id="T_77b8d_row19_col3" class="data row19 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_77b8d_level0_row20" class="row_heading level0 row20" >Augean Stables</th>
#       <td id="T_77b8d_row20_col0" cl

# %% [markdown]
# # Visualize prediction

# %%
x_predict_as_doc = model.predict(designs[:20], as_doc=True)

# %%
from spacy import displacy
colors = {'PERSON': 'mediumpurple','OBJECT': 'greenyellow', 'ANIMAL' : 'orange', 'PLANT': 'salmom', 'VERBS': 'skyblue'}
options = {'ent': ['PERSON', 'OBJECT', 'ANIMAL', 'PLANT'], 'colors': colors}
displacy.render(x_predict_as_doc.y[:10], 
                style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diademed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     head
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  of deified
# <mark class="entity" style="background: mediumpurple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexander the Great
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     horn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  of Ammon, right. Border of dots.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Altar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# , lighted and
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     garlanded
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Prize
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amphora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  on ornamental stand; within linear square and incuse square.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amphora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  with ribbed surface and crooked
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     handles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  containing two
# <mark class="entity" style="background: salmom; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ears of corn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLANT</span>
# </mark>
#  and
# <mark class="entity" style="background: salmom; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     poppy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLANT</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bust
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
#  of youthful
# <mark class="entity" style="background: mediumpurple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anchialos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , right, wearing
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     taenia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# . Border of dots.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Inverted
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anchor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# ; under left fluke,
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crayfish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANIMAL</span>
# </mark>
# , under right fluke, ethnicon.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Inverted
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anchor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# ; under left fluke,
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crayfish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANIMAL</span>
# </mark>
# , under right fluke, ethnicon; all within circular incuse.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Inverted
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anchor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OBJECT</span>
# </mark>
# ;  under right fluke,
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crayfish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANIMAL</span>
# </mark>
# , under left fluke, ethnicon.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Inverted
# <mark class="entity" style="background: greenyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anchor
#     <span style="font-size: 0.8em; font-weight: bold; line-

# %% [markdown]
# ## Upload data to mysql

# %%
upload = False

# %%
if upload ==True:
    dc =  Database_Connection("mysql+mysqlconnector://YourConnection")
    cnt_designs = dc.load_designs_from_db("designs", [id_col, design_col])
    cnt_pred = my_estimator.predict_clear(cnt_designs )
    cnt_pred_predictions_only = cnt_pred["y"]
    
    cnt_ner_output = pd.DataFrame([(str(designid), *relation) for  _, (designid, relation_list) in cnt_pred.iterrows()
                    for relation in relation_list],
            columns=["DesignID", "Entity", "Label_Entity"])

    cnt_ner_output.to_sql("cnt_pipeline_ner", dc.mysql_connection, 
                           if_exists="replace", index=False)
